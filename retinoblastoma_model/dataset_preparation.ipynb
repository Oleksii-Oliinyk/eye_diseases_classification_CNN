# %%
import cv2
import os
import random  
import numpy as np

# %%
def read_images(read_path):    
    images = []
    for filename in os.listdir(read_path):
        if filename.endswith((".png", ".jpg", ".jpeg")):
            img = cv2.imread(os.path.join(read_path, filename))
        if img is not None:
            images.append(img)
    print(f"Loaded {len(images)} images from {read_path}")
    return images

# %%
def process_images(images): 
    processed_images = []
    i = 0
    for image in images: 
        i+=1
        height, width, _ = image.shape
        if height == width:
            cropped_img = image
        a = abs(height - width)
        a1 = a // 2
        a2 = a1 if a % 2 == 0 else a1 + 1
        if height > width:
            cropped_img = image[a1:height-a2, 0:width]
        if height < width:
            cropped_img = image[0:height, a1:width-a2]
        
        processed_img = cv2.resize(cropped_img, (256, 256), interpolation = cv2.INTER_AREA)
        
        processed_images.append(processed_img)

    return processed_images

# %%
def save_images(images, save_path, name):
    i = 0
    for img in images:
        i += 1
        filename = f"{name}_{i}.png"
        cv2.imwrite(os.path.join(save_path, filename), img, [cv2.IMWRITE_PNG_COMPRESSION, 9])
        print(f"Photo {filename} saved to {save_path}")
    print("All photos were saved!!!")

# %%
healthy_eye_read_path = "dataset_phase_2/healthy/"
retinoblastoma_eye_read_path = "dataset_phase_2/retinoblastoma/"

# %%
dataset_folder = "processed_dataset/"

train_path = dataset_folder + "training/"
validation_path = dataset_folder + "validation/"

dataset_classes = ["healthy", "retinoblastoma"]

for dataset_class in dataset_classes:
    os.makedirs(train_path + dataset_class, exist_ok=True)
    os.makedirs(validation_path + dataset_class, exist_ok=True)

# %%
healthy_eye_images = read_images(healthy_eye_read_path)
retinoblastoma_eye_images = read_images(retinoblastoma_eye_read_path)
# Out:
# Loaded 127 images from dataset_phase_2/healthy/
# Loaded 109 images from dataset_phase_2/retinoblastoma/

# %%
processed_healthy_eye_images = process_images(healthy_eye_images)
processed_retinoblastoma_eye_images = process_images(retinoblastoma_eye_images)

# %%
random.shuffle(processed_healthy_eye_images)
split_index_healthy_eye = int(len(processed_healthy_eye_images) * 0.85)
train_healthy_eye_images = processed_healthy_eye_images[:split_index_healthy_eye]
validation_healthy_eye_images = processed_healthy_eye_images[split_index_healthy_eye:]

random.shuffle(processed_retinoblastoma_eye_images)
split_index_retinoblastoma_eye = int(len(processed_retinoblastoma_eye_images) * 0.85)
train_retinoblastoma_eye_images = processed_retinoblastoma_eye_images[:split_index_retinoblastoma_eye]
validation_retinoblastoma_eye_images = processed_retinoblastoma_eye_images[split_index_retinoblastoma_eye:]

# %%
print(len(train_healthy_eye_images))
print(len(validation_healthy_eye_images))
print(len(train_retinoblastoma_eye_images))
print(len(validation_retinoblastoma_eye_images))
# Out:
# 107
# 20
# 92
# 17

# %%
save_images(train_healthy_eye_images, train_path + dataset_classes[0], dataset_classes[0] + "_eye")
save_images(validation_healthy_eye_images, validation_path + dataset_classes[0], dataset_classes[0] + "_eye")

save_images(train_retinoblastoma_eye_images, train_path + dataset_classes[1], dataset_classes[1] + "_eye")
save_images(validation_retinoblastoma_eye_images, validation_path + dataset_classes[1], dataset_classes[1] + "_eye")
# Out:
# Photo healthy_eye_1.png saved to processed_dataset/training/healthy
# Photo healthy_eye_2.png saved to processed_dataset/training/healthy
# Photo healthy_eye_3.png saved to processed_dataset/training/healthy
# Photo healthy_eye_4.png saved to processed_dataset/training/healthy
# Photo healthy_eye_5.png saved to processed_dataset/training/healthy
# Photo healthy_eye_6.png saved to processed_dataset/training/healthy
# Photo healthy_eye_7.png saved to processed_dataset/training/healthy
# Photo healthy_eye_8.png saved to processed_dataset/training/healthy
# Photo healthy_eye_9.png saved to processed_dataset/training/healthy
# Photo healthy_eye_10.png saved to processed_dataset/training/healthy
# Photo healthy_eye_11.png saved to processed_dataset/training/healthy
# Photo healthy_eye_12.png saved to processed_dataset/training/healthy
# Photo healthy_eye_13.png saved to processed_dataset/training/healthy
# Photo healthy_eye_14.png saved to processed_dataset/training/healthy
# Photo healthy_eye_15.png saved to processed_dataset/training/healthy
# Photo healthy_eye_16.png saved to processed_dataset/training/healthy
# Photo healthy_eye_17.png saved to processed_dataset/training/healthy
# Photo healthy_eye_18.png saved to processed_dataset/training/healthy
# Photo healthy_eye_19.png saved to processed_dataset/training/healthy
# Photo healthy_eye_20.png saved to processed_dataset/training/healthy
# Photo healthy_eye_21.png saved to processed_dataset/training/healthy
# Photo healthy_eye_22.png saved to processed_dataset/training/healthy
# Photo healthy_eye_23.png saved to processed_dataset/training/healthy
# Photo healthy_eye_24.png saved to processed_dataset/training/healthy
# Photo healthy_eye_25.png saved to processed_dataset/training/healthy
# Photo healthy_eye_26.png saved to processed_dataset/training/healthy
# Photo healthy_eye_27.png saved to processed_dataset/training/healthy
# Photo healthy_eye_28.png saved to processed_dataset/training/healthy
# Photo healthy_eye_29.png saved to processed_dataset/training/healthy
# Photo healthy_eye_30.png saved to processed_dataset/training/healthy
# Photo healthy_eye_31.png saved to processed_dataset/training/healthy
# Photo healthy_eye_32.png saved to processed_dataset/training/healthy
# Photo healthy_eye_33.png saved to processed_dataset/training/healthy
# Photo healthy_eye_34.png saved to processed_dataset/training/healthy
# Photo healthy_eye_35.png saved to processed_dataset/training/healthy
# Photo healthy_eye_36.png saved to processed_dataset/training/healthy
# Photo healthy_eye_37.png saved to processed_dataset/training/healthy
# Photo healthy_eye_38.png saved to processed_dataset/training/healthy
# Photo healthy_eye_39.png saved to processed_dataset/training/healthy
# Photo healthy_eye_40.png saved to processed_dataset/training/healthy
# Photo healthy_eye_41.png saved to processed_dataset/training/healthy
# Photo healthy_eye_42.png saved to processed_dataset/training/healthy
# Photo healthy_eye_43.png saved to processed_dataset/training/healthy
# Photo healthy_eye_44.png saved to processed_dataset/training/healthy
# Photo healthy_eye_45.png saved to processed_dataset/training/healthy
# Photo healthy_eye_46.png saved to processed_dataset/training/healthy
# Photo healthy_eye_47.png saved to processed_dataset/training/healthy
# Photo healthy_eye_48.png saved to processed_dataset/training/healthy
# Photo healthy_eye_49.png saved to processed_dataset/training/healthy
# Photo healthy_eye_50.png saved to processed_dataset/training/healthy
# Photo healthy_eye_51.png saved to processed_dataset/training/healthy
# Photo healthy_eye_52.png saved to processed_dataset/training/healthy
# Photo healthy_eye_53.png saved to processed_dataset/training/healthy
# Photo healthy_eye_54.png saved to processed_dataset/training/healthy
# Photo healthy_eye_55.png saved to processed_dataset/training/healthy
# Photo healthy_eye_56.png saved to processed_dataset/training/healthy
# Photo healthy_eye_57.png saved to processed_dataset/training/healthy
# Photo healthy_eye_58.png saved to processed_dataset/training/healthy
# Photo healthy_eye_59.png saved to processed_dataset/training/healthy
# Photo healthy_eye_60.png saved to processed_dataset/training/healthy
# Photo healthy_eye_61.png saved to processed_dataset/training/healthy
# Photo healthy_eye_62.png saved to processed_dataset/training/healthy
# Photo healthy_eye_63.png saved to processed_dataset/training/healthy
# Photo healthy_eye_64.png saved to processed_dataset/training/healthy
# Photo healthy_eye_65.png saved to processed_dataset/training/healthy
# Photo healthy_eye_66.png saved to processed_dataset/training/healthy
# Photo healthy_eye_67.png saved to processed_dataset/training/healthy
# Photo healthy_eye_68.png saved to processed_dataset/training/healthy
# Photo healthy_eye_69.png saved to processed_dataset/training/healthy
# Photo healthy_eye_70.png saved to processed_dataset/training/healthy
# Photo healthy_eye_71.png saved to processed_dataset/training/healthy
# Photo healthy_eye_72.png saved to processed_dataset/training/healthy
# Photo healthy_eye_73.png saved to processed_dataset/training/healthy
# Photo healthy_eye_74.png saved to processed_dataset/training/healthy
# Photo healthy_eye_75.png saved to processed_dataset/training/healthy
# Photo healthy_eye_76.png saved to processed_dataset/training/healthy
# Photo healthy_eye_77.png saved to processed_dataset/training/healthy
# Photo healthy_eye_78.png saved to processed_dataset/training/healthy
# Photo healthy_eye_79.png saved to processed_dataset/training/healthy
# Photo healthy_eye_80.png saved to processed_dataset/training/healthy
# Photo healthy_eye_81.png saved to processed_dataset/training/healthy
# Photo healthy_eye_82.png saved to processed_dataset/training/healthy
# Photo healthy_eye_83.png saved to processed_dataset/training/healthy
# Photo healthy_eye_84.png saved to processed_dataset/training/healthy
# Photo healthy_eye_85.png saved to processed_dataset/training/healthy
# Photo healthy_eye_86.png saved to processed_dataset/training/healthy
# Photo healthy_eye_87.png saved to processed_dataset/training/healthy
# Photo healthy_eye_88.png saved to processed_dataset/training/healthy
# Photo healthy_eye_89.png saved to processed_dataset/training/healthy
# Photo healthy_eye_90.png saved to processed_dataset/training/healthy
# Photo healthy_eye_91.png saved to processed_dataset/training/healthy
# Photo healthy_eye_92.png saved to processed_dataset/training/healthy
# Photo healthy_eye_93.png saved to processed_dataset/training/healthy
# Photo healthy_eye_94.png saved to processed_dataset/training/healthy
# Photo healthy_eye_95.png saved to processed_dataset/training/healthy
# Photo healthy_eye_96.png saved to processed_dataset/training/healthy
# Photo healthy_eye_97.png saved to processed_dataset/training/healthy
# Photo healthy_eye_98.png saved to processed_dataset/training/healthy
# Photo healthy_eye_99.png saved to processed_dataset/training/healthy
# Photo healthy_eye_100.png saved to processed_dataset/training/healthy
# Photo healthy_eye_101.png saved to processed_dataset/training/healthy
# Photo healthy_eye_102.png saved to processed_dataset/training/healthy
# Photo healthy_eye_103.png saved to processed_dataset/training/healthy
# Photo healthy_eye_104.png saved to processed_dataset/training/healthy
# Photo healthy_eye_105.png saved to processed_dataset/training/healthy
# Photo healthy_eye_106.png saved to processed_dataset/training/healthy
# Photo healthy_eye_107.png saved to processed_dataset/training/healthy
# All photos were saved!!!
# Photo healthy_eye_1.png saved to processed_dataset/validation/healthy
# Photo healthy_eye_2.png saved to processed_dataset/validation/healthy
# Photo healthy_eye_3.png saved to processed_dataset/validation/healthy
# Photo healthy_eye_4.png saved to processed_dataset/validation/healthy
# Photo healthy_eye_5.png saved to processed_dataset/validation/healthy
# Photo healthy_eye_6.png saved to processed_dataset/validation/healthy
# Photo healthy_eye_7.png saved to processed_dataset/validation/healthy
# Photo healthy_eye_8.png saved to processed_dataset/validation/healthy
# Photo healthy_eye_9.png saved to processed_dataset/validation/healthy
# Photo healthy_eye_10.png saved to processed_dataset/validation/healthy
# Photo healthy_eye_11.png saved to processed_dataset/validation/healthy
# Photo healthy_eye_12.png saved to processed_dataset/validation/healthy
# Photo healthy_eye_13.png saved to processed_dataset/validation/healthy
# Photo healthy_eye_14.png saved to processed_dataset/validation/healthy
# Photo healthy_eye_15.png saved to processed_dataset/validation/healthy
# Photo healthy_eye_16.png saved to processed_dataset/validation/healthy
# Photo healthy_eye_17.png saved to processed_dataset/validation/healthy
# Photo healthy_eye_18.png saved to processed_dataset/validation/healthy
# Photo healthy_eye_19.png saved to processed_dataset/validation/healthy
# Photo healthy_eye_20.png saved to processed_dataset/validation/healthy
# All photos were saved!!!
# Photo retinoblastoma_eye_1.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_2.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_3.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_4.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_5.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_6.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_7.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_8.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_9.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_10.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_11.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_12.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_13.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_14.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_15.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_16.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_17.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_18.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_19.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_20.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_21.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_22.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_23.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_24.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_25.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_26.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_27.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_28.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_29.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_30.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_31.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_32.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_33.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_34.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_35.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_36.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_37.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_38.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_39.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_40.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_41.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_42.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_43.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_44.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_45.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_46.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_47.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_48.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_49.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_50.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_51.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_52.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_53.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_54.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_55.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_56.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_57.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_58.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_59.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_60.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_61.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_62.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_63.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_64.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_65.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_66.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_67.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_68.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_69.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_70.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_71.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_72.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_73.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_74.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_75.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_76.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_77.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_78.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_79.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_80.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_81.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_82.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_83.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_84.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_85.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_86.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_87.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_88.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_89.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_90.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_91.png saved to processed_dataset/training/retinoblastoma
# Photo retinoblastoma_eye_92.png saved to processed_dataset/training/retinoblastoma
# All photos were saved!!!
# Photo retinoblastoma_eye_1.png saved to processed_dataset/validation/retinoblastoma
# Photo retinoblastoma_eye_2.png saved to processed_dataset/validation/retinoblastoma
# Photo retinoblastoma_eye_3.png saved to processed_dataset/validation/retinoblastoma
# Photo retinoblastoma_eye_4.png saved to processed_dataset/validation/retinoblastoma
# Photo retinoblastoma_eye_5.png saved to processed_dataset/validation/retinoblastoma
# Photo retinoblastoma_eye_6.png saved to processed_dataset/validation/retinoblastoma
# Photo retinoblastoma_eye_7.png saved to processed_dataset/validation/retinoblastoma
# Photo retinoblastoma_eye_8.png saved to processed_dataset/validation/retinoblastoma
# Photo retinoblastoma_eye_9.png saved to processed_dataset/validation/retinoblastoma
# Photo retinoblastoma_eye_10.png saved to processed_dataset/validation/retinoblastoma
# Photo retinoblastoma_eye_11.png saved to processed_dataset/validation/retinoblastoma
# Photo retinoblastoma_eye_12.png saved to processed_dataset/validation/retinoblastoma
# Photo retinoblastoma_eye_13.png saved to processed_dataset/validation/retinoblastoma
# Photo retinoblastoma_eye_14.png saved to processed_dataset/validation/retinoblastoma
# Photo retinoblastoma_eye_15.png saved to processed_dataset/validation/retinoblastoma
# Photo retinoblastoma_eye_16.png saved to processed_dataset/validation/retinoblastoma
# Photo retinoblastoma_eye_17.png saved to processed_dataset/validation/retinoblastoma
# All photos were saved!!!
