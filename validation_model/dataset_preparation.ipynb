# %%
import cv2
import os

# %%
def read_images(read_path):    
    images = []
    for filename in os.listdir(read_path):
        if filename.endswith((".png", ".jpg", ".jpeg")):
            img = cv2.imread(os.path.join(read_path, filename))
        if img is not None:
            images.append(img)
    print(f"Loaded {len(images)} images from {read_path}")
    return images

# %%
def process_images(images, save_path, name): 
    i = 0
    for image in images: 
        i+=1
        gray_img = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
        height, width = gray_img.shape
        if height == width:
            cropped_img = gray_img
        a = abs(height - width)
        a1 = a // 2
        a2 = a1 if a % 2 == 0 else a1 + 1
        if height > width:
            cropped_img = gray_img[a1:height-a2, 0:width]
        if height < width:
            cropped_img = gray_img[0:height, a1:width-a2]
        resized_img = cv2.resize(cropped_img, (128, 128))

        filename = f"{name}_{i}.png"
        cv2.imwrite(os.path.join(save_path, filename), resized_img, [cv2.IMWRITE_PNG_COMPRESSION, 9])
        print(f"Photo {filename} saved to {save_path}")

    print("All photos in folder were processed!!!")

# %%
save_path_eye = "processed_dataset/eye/"
save_path_not_eye = "processed_dataset/not_eye/"
os.makedirs(save_path_eye, exist_ok=True)
os.makedirs(save_path_not_eye, exist_ok=True)

# %%
bad_eye_read_path = "unproccesed_dataset/no_eye/bad_eye"
face_read_path = "unproccesed_dataset/no_eye/face"
fake_eye_read_path = "unproccesed_dataset/no_eye/fake_eye"
random_img_read_path = "unproccesed_dataset/no_eye/random"

# %%
bad_eye_images = read_images(bad_eye_read_path)
face_images = read_images(face_read_path)
fake_eye_images = read_images(fake_eye_read_path)
random_images = read_images(random_img_read_path)
# Out:
# Loaded 1662 images from unproccesed_dataset/no_eye/bad_eye
# Loaded 350 images from unproccesed_dataset/no_eye/face
# Loaded 48 images from unproccesed_dataset/no_eye/fake_eye
# Loaded 700 images from unproccesed_dataset/no_eye/random

# %%
# process_images(bad_eye_images,  save_path_not_eye, "bad_eye")
# process_images(face_images,     save_path_not_eye, "face")
# process_images(fake_eye_images, save_path_not_eye, "fake_eye")
# process_images(random_images,   save_path_not_eye, "random_images")
# Out:
# Photo face_1.png saved to processed_dataset/not_eye/
# Photo face_2.png saved to processed_dataset/not_eye/
# Photo face_3.png saved to processed_dataset/not_eye/
# Photo face_4.png saved to processed_dataset/not_eye/
# Photo face_5.png saved to processed_dataset/not_eye/
# Photo face_6.png saved to processed_dataset/not_eye/
# Photo face_7.png saved to processed_dataset/not_eye/
# Photo face_8.png saved to processed_dataset/not_eye/
# Photo face_9.png saved to processed_dataset/not_eye/
# Photo face_10.png saved to processed_dataset/not_eye/
# Photo face_11.png saved to processed_dataset/not_eye/
# Photo face_12.png saved to processed_dataset/not_eye/
# Photo face_13.png saved to processed_dataset/not_eye/
# Photo face_14.png saved to processed_dataset/not_eye/
# Photo face_15.png saved to processed_dataset/not_eye/
# Photo face_16.png saved to processed_dataset/not_eye/
# Photo face_17.png saved to processed_dataset/not_eye/
# Photo face_18.png saved to processed_dataset/not_eye/
# ...

# %%
eye_read_path = "unproccesed_dataset/eye"
eye_images = read_images(eye_read_path)
process_images(eye_images, save_path_eye, "eye")
# Out:
# Loaded 1820 images from unproccesed_dataset/eye
# Photo eye_1.png saved to processed_dataset/eye/
# Photo eye_2.png saved to processed_dataset/eye/
# Photo eye_3.png saved to processed_dataset/eye/
# Photo eye_4.png saved to processed_dataset/eye/
# Photo eye_5.png saved to processed_dataset/eye/
# Photo eye_6.png saved to processed_dataset/eye/
# Photo eye_7.png saved to processed_dataset/eye/
# Photo eye_8.png saved to processed_dataset/eye/
# Photo eye_9.png saved to processed_dataset/eye/
# Photo eye_10.png saved to processed_dataset/eye/
# Photo eye_11.png saved to processed_dataset/eye/
# Photo eye_12.png saved to processed_dataset/eye/
# Photo eye_13.png saved to processed_dataset/eye/
# Photo eye_14.png saved to processed_dataset/eye/
# Photo eye_15.png saved to processed_dataset/eye/
# Photo eye_16.png saved to processed_dataset/eye/
# Photo eye_17.png saved to processed_dataset/eye/
# Photo eye_18.png saved to processed_dataset/eye/
# ...
